# %% [markdown]
# # Machine Learning model for predicting life expectancy

# %% [markdown]
# ### 1. Importing libraries

# %%
import matplotlib.pyplot as plt

# %%
#importing data manipulation and machine learning libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 2. Collecting data

# %%
#importing dataset from .csv file
ds = pd.read_csv("Life Expectancy Data.csv")

# %%
#showing the first 3 lines
ds.head(3)
# Out:
#        Country  Year      Status  Life_expect  Adult_Mortality  infant_deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
#
#    Alcohol  percentage_expenditure  HepatitisB  Measles  ...  Polio  \
# 0     0.01               71.279624        65.0     1154  ...    6.0
# 1     0.01               73.523582        62.0      492  ...   58.0
# 2     0.01               73.219243        64.0      430  ...   62.0
#
#    Total_expenditure  Diphtheria  HIV_AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210  33736494.0
# 1               8.18        62.0       0.1  612.696514    327582.0
# 2               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness_1-19_years  thinness_5-9_years  Income_composition_of_resources  \
# ...

# %%
#showing the last 3 lines
ds.tail(3)
# Out:
#        Country  Year      Status  Life_expect  Adult_Mortality  infant_deaths  \
# 2935  Zimbabwe  2002  Developing         44.8             73.0             25
# 2936  Zimbabwe  2001  Developing         45.3            686.0             25
# 2937  Zimbabwe  2000  Developing         46.0            665.0             24
#
#       Alcohol  percentage_expenditure  HepatitisB  Measles  ...  Polio  \
# 2935     4.43                     0.0        73.0      304  ...   73.0
# 2936     1.72                     0.0        76.0      529  ...   76.0
# 2937     1.68                     0.0        79.0     1483  ...   78.0
#
#       Total_expenditure  Diphtheria  HIV_AIDS         GDP  Population  \
# 2935               6.53        71.0      39.8   57.348340    125525.0
# 2936               6.16        75.0      42.1  548.587312  12366165.0
# 2937               7.10        78.0      43.5  547.358878  12222251.0
#
#       thinness_1-19_years  thinness_5-9_years  \
# ...

# %%
#viewing the dataset size
ds.shape
# Out:
# (2938, 22)

# %%
#"Verifying the data types of each column in the dataset"
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expect                      2928 non-null   float64
#  4   Adult_Mortality                  2928 non-null   float64
#  5   infant_deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   HepatitisB                       2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under_five_deaths                2938 non-null   int64
# ...

# %%
# showing a statystical summary of the dataset
ds.describe()
# Out:
#               Year  Life_expect  Adult_Mortality  infant_deaths      Alcohol  \
# count  2938.000000  2928.000000      2928.000000    2938.000000  2744.000000
# mean   2007.518720    69.224932       164.796448      30.303948     4.602861
# std       4.613841     9.523867       124.292079     117.926501     4.052413
# min    2000.000000    36.300000         1.000000       0.000000     0.010000
# 25%    2004.000000    63.100000        74.000000       0.000000     0.877500
# 50%    2008.000000    72.100000       144.000000       3.000000     3.755000
# 75%    2012.000000    75.700000       228.000000      22.000000     7.702500
# max    2015.000000    89.000000       723.000000    1800.000000    17.870000
#
#        percentage_expenditure   HepatitisB        Measles          BMI  \
# count             2938.000000  2385.000000    2938.000000  2904.000000
# mean               738.251295    80.940461    2419.592240    38.321247
# ...

# %% [markdown]
# ### 3. Preparing the data

# %%
# Counting null values
ds.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expect                         10
# Adult_Mortality                     10
# infant_deaths                        0
# Alcohol                            194
# percentage_expenditure               0
# HepatitisB                         553
# Measles                              0
# BMI                                 34
# under_five_deaths                    0
# Polio                               19
# Total_expenditure                  226
# Diphtheria                          19
# HIV_AIDS                             0
# GDP                                448
# Population                         652
# thinness_1-19_years                 34
# thinness_5-9_years                  34
# Income_composition_of_resources    167
# Schooling                          163
# dtype: int64

# %%
ds.nunique().sort_values(ascending = False).values
# Out:
# array([2490, 2328, 2278, 1076,  958,  818,  625,  608,  425,  362,  252,
#         209,  207,  200,  200,  193,  173,   87,   81,   73,   16,    2],
#       dtype=int64)

# %%
# Visualizing the above information in graphical mode
fig, ax = plt.subplots()

ax.bar(ds.nunique().sort_values(ascending = False).index, ds.nunique().sort_values(ascending = False).values, color = '#ADD8E6')

ax.tick_params(axis = 'x', labelrotation = 90)

plt.show()

# %%
# Verifying the life_expect histogram
fig, ax = plt.subplots()

ax.hist(ds.Life_expect, bins=20, color = '#ADD8E6')

plt.show()

# %% [markdown]
# ### Boxplot Visualization

# %%
# Verifying for the Life_expect Column
fig, ax = plt.subplots()

ax.boxplot(ds.Population)

plt.show()

# %% [markdown]
# ### 4. Analyzing the incoming data

# %% [markdown]
# ### 5. Verifying the data

# %% [markdown]
# ### 6. Training the machine learning model

# %% [markdown]
# ### 7. Testing the algorithmyc
